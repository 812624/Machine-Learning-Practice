# %%
# Importing all necessary packages
import pandas as pd
import numpy as np
from sklearn import  linear_model
from sklearn.cross_validation import train_test_split
import matplotlib.pyplot as plt

# %%
# Opening .csv file using pandas
file = "/home/sakshi/Desktop/mlp/testdata.csv"
data = pd.read_csv(file)
data
# Out:
#           X         Y
# 0    6.1101  17.59200
# 1    5.5277   9.13020
# 2    8.5186  13.66200
# 3    7.0032  11.85400
# 4    5.8598   6.82330
# 5    8.3829  11.88600
# 6    7.4764   4.34830
# 7    8.5781  12.00000
# 8    6.4862   6.59870
# 9    5.0546   3.81660
# 10   5.7107   3.25220
# 11  14.1640  15.50500
# 12   5.7340   3.15510
# 13   8.4084   7.22580
# 14   5.6407   0.71618
# 15   5.3794   3.51290
# 16   6.3654   5.30480
# 17   5.1301   0.56077
# 18   6.4296   3.65180
# 19   7.0708   5.38930
# 20   6.1891   3.13860
# 21  20.2700  21.76700
# 22   5.4901   4.26300
# 23   6.3261   5.18750
# 24   5.5649   3.08250
# 25  18.9450  22.63800
# 26  12.8280  13.50100
# 27  10.9570   7.04670
# 28  13.1760  14.69200
# 29  22.2030  24.14700
# ..      ...       ...
# 67  10.2360   7.77540
# 68   5.4994   1.01730
# 69  20.3410  20.99200
# 70  10.1360   6.67990
# 71   7.3345   4.02590
# 72   6.0062   1.27840
# 73   7.2259   3.34110
# 74   5.0269  -2.68070
# 75   6.5479   0.29678
# ...

# %%
# Assigning single feature to data_x
data_x = data['X']

# Reshaping data if data has a single feature
data_x = data_x.values.reshape(-1,1)

# Assigning corresponding y value to data_y
data_y = data['Y']

# Applying linear regression
linReg = linear_model.LinearRegression()

# Dividing data in x_train, y_train and x_test, y_test in standard ratio of 0.8+0.2 
x_train, x_test, y_train, y_test = train_test_split(data_x, data_y, test_size=0.2)
linReg.fit(x_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
# Sampling x_test
a = linReg.predict(x_test)
a[5]
# Out:
# 2.9366850668990159

# %%
# Corresponding values of y_test for selected x_test
y_test
# Out:
# 18     3.65180
# 44     6.73180
# 65     4.88520
# 75     0.29678
# 85     4.24150
# 33     1.84950
# 57     4.60420
# 41     3.91150
# 8      6.59870
# 1      9.13020
# 49     1.01790
# 7     12.00000
# 34     6.54260
# 45     1.04630
# 77     5.70140
# 12     3.15510
# 22     4.26300
# 71     4.02590
# 30    -1.22000
# 92     7.20290
# Name: Y, dtype: float64

# %%
# Plotting the data
plt.plot()
plt.scatter(x_train, y_train, color="b", label="train data")
plt.scatter(x_test, y_test, color="r", label="test data")
plt.plot(x_train, linReg.predict(x_train), color="black")
plt.legend(loc=7)
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
# Mean square error
np.mean((linReg.predict(x_test) - y_test)**2)
# Out:
# 8.566732233119243
